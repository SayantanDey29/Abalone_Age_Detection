# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data=pd.read_csv("/content/abalone.csv")

# %%
data.head()
# Out:
#    Unnamed: 0 Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0           0   M   0.455     0.365   0.095        0.5140          0.2245
# 1           1   M   0.350     0.265   0.090        0.2255          0.0995
# 2           2   F   0.530     0.420   0.135        0.6770          0.2565
# 3           3   M   0.440     0.365   0.125        0.5160          0.2155
# 4           4   I   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      4177 non-null   int64
#  1   Sex             4177 non-null   object
#  2   Length          4177 non-null   float64
#  3   Diameter        4177 non-null   float64
#  4   Height          4177 non-null   float64
#  5   Whole weight    4177 non-null   float64
#  6   Shucked weight  4177 non-null   float64
#  7   Viscera weight  4177 non-null   float64
#  8   Shell weight    4177 non-null   float64
#  9   Rings           4177 non-null   int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 326.5+ KB

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Sex', 'Length', 'Diameter', 'Height', 'Whole weight',
#        'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
data.describe()
# Out:
#         Unnamed: 0       Length     Diameter       Height  Whole weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean   2088.000000     0.523992     0.407881     0.139516      0.828742
# std    1205.940366     0.120093     0.099240     0.041827      0.490389
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%    1044.000000     0.450000     0.350000     0.115000      0.441500
# 50%    2088.000000     0.545000     0.425000     0.140000      0.799500
# 75%    3132.000000     0.615000     0.480000     0.165000      1.153000
# max    4176.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked weight  Viscera weight  Shell weight        Rings
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831     9.933684
# std          0.221963        0.109614      0.139203     3.224169
# min          0.001000        0.000500      0.001500     1.000000
# 25%          0.186000        0.093500      0.130000     8.000000
# 50%          0.336000        0.171000      0.234000     9.000000
# 75%          0.502000        0.253000      0.329000    11.000000
# max          1.488000        0.760000      1.005000    29.000000

# %%
data.drop(index=data[data.Height==0].index,axis=0,inplace=True)

# %%
data.describe()
# Out:
#         Unnamed: 0       Length    Diameter       Height  Whole weight  \
# count  4175.000000  4175.000000  4175.00000  4175.000000   4175.000000
# mean   2087.742036     0.524065     0.40794     0.139583      0.829005
# std    1205.799036     0.120069     0.09922     0.041725      0.490349
# min       0.000000     0.075000     0.05500     0.010000      0.002000
# 25%    1043.500000     0.450000     0.35000     0.115000      0.442250
# 50%    2088.000000     0.545000     0.42500     0.140000      0.800000
# 75%    3131.500000     0.615000     0.48000     0.165000      1.153500
# max    4176.000000     0.815000     0.65000     1.130000      2.825500
#
#        Shucked weight  Viscera weight  Shell weight        Rings
# count     4175.000000     4175.000000   4175.000000  4175.000000
# mean         0.359476        0.180653      0.238834     9.935090
# std          0.221954        0.109605      0.139212     3.224227
# min          0.001000        0.000500      0.001500     1.000000
# 25%          0.186250        0.093500      0.130000     8.000000
# 50%          0.336000        0.171000      0.234000     9.000000
# 75%          0.502000        0.253000      0.328750    11.000000
# max          1.488000        0.760000      1.005000    29.000000

# %%
data.isnull().sum()
# Out:
# Unnamed: 0        0
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
data.Sex.value_counts()
# Out:
# M    1528
# I    1340
# F    1307
# Name: Sex, dtype: int64

# %%
data.Rings.value_counts().sort_index(ascending=False)
# Out:
# 29      1
# 27      2
# 26      1
# 25      1
# 24      2
# 23      9
# 22      6
# 21     14
# 20     26
# 19     32
# 18     42
# 17     58
# 16     67
# 15    103
# 14    126
# 13    203
# 12    267
# 11    487
# 10    634
# 9     689
# 8     567
# 7     391
# 6     258
# 5     115
# 4      57
# 3      15
# 2       1
# 1       1
# Name: Rings, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
sns.boxplot(x='Sex',y='Rings',data=data)
plt.show()

# %%
sns.countplot(x='Sex',data=data)
plt.show()

# %%
data.hist(figsize=(20,10))
plt.show()

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Sex', 'Length', 'Diameter', 'Height', 'Whole weight',
#        'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
data.head()
# Out:
#    Unnamed: 0 Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0           0   M   0.455     0.365   0.095        0.5140          0.2245
# 1           1   M   0.350     0.265   0.090        0.2255          0.0995
# 2           2   F   0.530     0.420   0.135        0.6770          0.2565
# 3           3   M   0.440     0.365   0.125        0.5160          0.2155
# 4           4   I   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %%
cols=data.columns[1:8]
cols
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight'],
#       dtype='object')

# %%
for x in cols:
  sns.scatterplot(x=x,y='Rings',data=data,hue='Sex')
  plt.show()

# %%
data.skew().sort_values(ascending=False)
# Out:
# <ipython-input-24-e4bfbe835357>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.skew().sort_values(ascending=False)
# Height            3.166364
# Rings             1.113754
# Shucked weight    0.718735
# Shell weight      0.621081
# Viscera weight    0.591455
# Whole weight      0.530549
# Unnamed: 0       -0.000229
# Diameter         -0.610182
# Length           -0.640993
# dtype: float64

# %%
def outlier(col):
  d=x[col]
  q1=d.quantile(0.25)
  q3=d.quantile(0.75)
  iqr=q3-q1
  lower=q1-1.5*iqr
  upper=q3+1.5*iqr
  print("Outlier:",col)
  print((d[(d<lower) | (d>upper)]),lower,upper,iqr)

# %%
def outlier_handler(col):
  d=x[col]
  q1=d.quantile(0.25)
  q3=d.quantile(0.75)
  iqr=q3-q1
  lower=q1-1.5*iqr
  upper=q3+1.5*iqr
  print("Outlier:",col)
  d=d.clip(lower,upper)

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data.corr(),annot=True,fmt='.1f',cmap='RdBu')
plt.show()
# Out:
# <ipython-input-28-3ad03eb0b82a>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True,fmt='.1f',cmap='RdBu')

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
data['Sex']=encoder.fit_transform(data['Sex'])

# %%
x=data.drop(['Rings'],axis=1)
y=data.Rings

# %%
y.shape
# Out:
# (4175,)

# %%
x.head()
# Out:
#    Unnamed: 0  Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0           0    2   0.455     0.365   0.095        0.5140          0.2245
# 1           1    2   0.350     0.265   0.090        0.2255          0.0995
# 2           2    0   0.530     0.420   0.135        0.6770          0.2565
# 3           3    2   0.440     0.365   0.125        0.5160          0.2155
# 4           4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight
# 0          0.1010         0.150
# 1          0.0485         0.070
# 2          0.1415         0.210
# 3          0.1140         0.155
# 4          0.0395         0.055

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler

# %%
continious=x.columns[1:]

# %%
continious
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight'],
#       dtype='object')

# %%
for c in continious:
  outlier_handler(c)
# Out:
# Outlier: Sex
# Outlier: Length
# Outlier: Diameter
# Outlier: Height
# Outlier: Whole weight
# Outlier: Shucked weight
# Outlier: Viscera weight
# Outlier: Shell weight

# %%
scaler=StandardScaler()
continious=x.columns[1:]
for c in continious:
  x[[c]]=scaler.fit_transform(x[[c]])

# %%
x.head()
# Out:
#    Unnamed: 0       Sex    Length  Diameter    Height  Whole weight  \
# 0           0  1.151675 -0.575276 -0.432829 -1.068619     -0.642485
# 1           1  1.151675 -1.449876 -1.440813 -1.188465     -1.230912
# 2           2 -1.280415  0.049438  0.121562 -0.109856     -0.310030
# 3           3  1.151675 -0.700219 -0.432829 -0.349547     -0.638406
# 4           4 -0.064370 -1.616466 -1.541611 -1.428155     -1.272724
#
#    Shucked weight  Viscera weight  Shell weight
# 0       -0.608200       -0.726809     -0.638195
# 1       -1.171446       -1.205857     -1.212926
# 2       -0.464009       -0.357258     -0.207146
# 3       -0.648754       -0.608188     -0.602274
# 4       -1.216506       -1.287980     -1.320688

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
# Out:
# (2922, 9) (2922,)
# (1253, 9) (1253,)

# %%
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

model=KNeighborsRegressor(n_neighbors=5,weights='distance',algorithm='brute',p=3)
model.fit(x_train,y_train)
ans=model.predict(x_test)

# %%
ans
# Out:
# array([12.06032356, 10.61945289,  8.14115686, ..., 10.61698826,
#         7.40396318, 11.25534802])

# %%
ans=pd.DataFrame(ans,columns=['predicted'])

# %%
ans.head()
# Out:
#    predicted
# 0  12.060324
# 1  10.619453
# 2   8.141157
# 3  13.154399
# 4   9.778069

# %%
ans.shape
# Out:
# (1253, 1)

# %%
y_test.shape
# Out:
# (1253,)

# %%
y_true=pd.DataFrame(y_test.values)

# %%
y_true["new"]=ans['predicted']
y_true.tail()
# Out:
#        0        new
# 1248   7   6.254304
# 1249  12  11.362513
# 1250   7  10.616988
# 1251   6   7.403963
# 1252  18  11.255348

# %%
from sklearn.metrics import r2_score,mean_squared_error
error_c=r2_score(y_test,ans)
rme=mean_squared_error(y_test,ans,squared=False)
print(error_c,rme)
# Out:
# 0.49000823731331933 2.345900665826711
